# %%
# ch5_5.py
print("計算最終成績")
score = input("請輸入分數")
sc = int(score)
if (sc >=90):
    print(" A")
elif (sc >=80):
    print(" B")
elif (sc >=70):
    print(" C")
elif (sc >=60):
    print(" D")
else:    
    print(" F")
# Out:
# 計算最終成績
# 請輸入分數 78
#  C

# %%
print("計算生肖")
year = int(input("請輸入西元年"))
rem = (year -1900) % 12
if (rem ==0):
    print(" 鼠")
elif (rem ==1):
    print(" 牛")
elif (rem ==2):
    print(" 虎")
elif (rem ==3):
    print(" 兔")
elif (rem ==4):
    print(" 龍")
elif (rem ==5):
    print(" 蛇")
elif (rem ==6):
    print(" 馬")
elif (rem ==7):
    print(" 羊")
elif (rem ==8):
    print(" 猴")
elif (rem ==9):
    print(" 雞")
elif (rem ==10):
    print(" 狗")
else:    
    print(" 豬")
# Out:
# 計算生肖
# 請輸入西元年 2010
#  虎

# %%
# ch6_2.py
james = [23, 19, 22, 31, 18]
print("列印james第1場得分", james[0])
print("列印james第2場得分", james[1])
print("列印james第3場得分", james[2])
print("列印james第4場得分", james[3])
print("列印james第5場得分", james[4])
# Out:
# 列印james第1場得分 23
# 列印james第2場得分 19
# 列印james第3場得分 22
# 列印james第4場得分 31
# 列印james第5場得分 18

# %%
score = [90, 85, 75, 65, 44]
print("列印第一位同學的成績", score[0])
print("列印第二位同學的成績", score[1])
print("列印第三位同學的成績", score[2])
print("列印第四位同學的成績", score[3])
print("列印第五位同學的成績", score[4])
# Out:
# 列印第一位同學的成績 90
# 列印第二位同學的成績 85
# 列印第三位同學的成績 75
# 列印第四位同學的成績 65
# 列印第五位同學的成績 44

# %%
# ch6_5.py
james = [23, 19, 22, 31, 18]
print("列印james第1-3場得分", james[0:3])
print("列印james第2-4場得分", james[1:4])
print("列印james第1,3,5場得分", james[0:6:2])
# Out:
# 列印james第1-3場得分 [23, 19, 22]
# 列印james第2-4場得分 [19, 22, 31]
# 列印james第1,3,5場得分 [23, 22, 18]

# %%
# ch6_11.py
james = [23, 19, 22, 31, 18]
print("舊的James比賽分數", james)
james[4] =28
print("新的James比賽分數", james)
# Out:
# 舊的James比賽分數 [23, 19, 22, 31, 18]
# 新的James比賽分數 [23, 19, 22, 31, 28]

# %%
# 練習
score = [90, 80, 88, 84, 85, 87, 88, 89, 90, 100]
print("10位同學數學成績", score)
score[0] = 100
print("第一位同學數學成績", score)
score[9] = 90
print("最後一位同學數學成績", score)
# Out:
# 10位同學數學成績 [90, 80, 88, 84, 85, 87, 88, 89, 90, 100]
# 第一位同學數學成績 [100, 80, 88, 84, 85, 87, 88, 89, 90, 100]
# 最後一位同學數學成績 [100, 80, 88, 84, 85, 87, 88, 89, 90, 90]

# %%
#ch6_24.py
cars = []
print("目前串列內容 = ", cars)
cars.append('Honda')
print("目前串列內容 = ", cars)
cars.append('Toyota')
print("目前串列內容 = ", cars)
cars.append('Ford')
print("目前串列內容 = ", cars)
# Out:
# 目前串列內容 =  []
# 目前串列內容 =  ['Honda']
# 目前串列內容 =  ['Honda', 'Toyota']
# 目前串列內容 =  ['Honda', 'Toyota', 'Ford']

# %%
james = [23, 19, 22, 31, 18]
print("比賽最高得分 = ", max(james))
print("比賽最低得分 = ", min(james))
print("比賽得分總計 = ", sum(james))
print("比賽比了%d場比賽", len(james))
# Out:
# 比賽最高得分 =  31
# 比賽最低得分 =  18
# 比賽得分總計 =  113
# 比賽比了5場比賽 5

# %%
#ch7_3.py
players = ['Curry', 'Jordan', 'James', 'Durant', 'Obama']
for player in players:
    print(player)
# Out:
# Curry
# Jordan
# James
# Durant
# Obama

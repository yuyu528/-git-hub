# %%
print ("hi")
# Out:
# hi

# %%
y=^2
# Out:
#   Cell In[2], line 1
#     y=^2
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 程式實例ch3_24py : 從地球到月球約是384400公里，假設火箭的速度是一馬赫，設計一個程式計算需多少天，多少小時才可抵達月球。這個程式省略分鐘數。

# %%
# ch3_24.py
dist = 384400
speed = 1225
total_hours = dist // speed
days = tptal_hours // 24
hours = total_hours % 24
print("總共需要天數")
print(days)
print("小時數")
print(hours)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 speed = 1225
#       4 total_hours = dist // speed
# ----> 5 days = tptal_hours // 24
#       6 hours = total_hours % 24
#       7 print("總共需要天數")
#
# NameError: name 'tptal_hours' is not defined

# %%
# ch3_24.py
dist = 384400                 #地球到月球的距離
speed = 1225                  #馬赫速度每小時1225公里
total_hours = dist // speed   #計算小時數
days = total_hours // 24      #商 = 計算天數
hours = total_hours % 24      #餘數 = 計算小時數
print("總共需要天數")
print(days)
print("小時數")
print(hours)
# Out:
# 總共需要天數
# 13
# 小時數
# 1

# %%
# ch3_24.py
dist = 10000                 #地球到月球的距離
speed = 1225                  #馬赫速度每小時1225公里
total_hours = dist // speed   #計算小時數
days = total_hours // 24      #商 = 計算天數
hours = total_hours % 24      #餘數 = 計算小時數
print("總共需要天數")
print(days)
print("小時數")
print(hours)
# Out:
# 總共需要天數
# 0
# 小時數
# 8

# %%
name = input("請輸入姓名")
engh = input ("請輸入成績")
print("name資料類型是", type(name))
print("engh資料類型是", type(engh))
# Out:
# 請輸入姓名 yu
# 請輸入成績 100
# name資料類型是 <class 'str'>
# engh資料類型是 <class 'str'>

# %%
print("歡迎使用成績輸入系統")
name = input("請輸入姓名")
engh = input("請輸入英文成績")
math = input("請輸入數學成績")
total = int(engh) + int(math)
print("%s 你的總分是 %d" % (name, total))

# %% [raw]
# print("基數偶數判斷")
# num = input("請輸入任意整值")
# rem = int(num) % 2
# if (rem == 0):
#     print("%d 是偶數" % int(num))
# else:
#     print("%d 是奇數" % (num))

# %%
print("3的倍數判斷")
num = input("請輸入任意整值")
rem = int(num) % 3
if (rem == 0):
    print("%d 是3的倍數" % int(num))
else:
    print("%d 不是3的倍數" % (num))
# Out:
# 3的倍數判斷
# 請輸入任意整值 44
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       5     print("%d 是3的倍數" % int(num))
#       6 else:
# ----> 7     print("%d 不是3的倍數" % (num))
#
# TypeError: %d format: a real number is required, not str

# %%
print("3的倍數判斷")
num = input("請輸入任意整值")
rem = int(num) % 3
if (rem == 0):
    print("%d 是3的倍數" % int(num))
else:
    print("%d 不是3的倍數" % int(num))
# Out:
# 3的倍數判斷
# 請輸入任意整值 44
# 44 不是3的倍數
